# %% [markdown]
# # Libraries :
# - Set of classes, functions, and modules, where they are pre written codes to perform some tasks

# %% [markdown]
# ### 1. Pandas libraries
# - Library for data analysis

# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_csv(filepath_or_buffer = "C:\Jupyter\libraries\insurance.csv")
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
customer_file =pd.read_csv(filepath_or_buffer ="insurance.csv")

# %%
customer_file
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ## Notes :
# - 1. .csv = comma separated files
#   2. read = a function that reads any file formats
#   3. tab = library opens. Use after texting '.' after mentioning library get a function from there to execute
#   4. shift + tab (inside paranthesis) = signature. Read csv files as dataframe. LHS = arguments. RHS = parameters. consider path as string. (Should give file path or file name)
#   5. r = read. Use when filepath or csv file are in different folder.

# %% [markdown]
# # Numpy
# - Library used for numerical operations.

# %%
import numpy as np

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
np.repeat(a=customer_file,repeats=4,axis=1)
# Out:
# array([[1, 1, 1, ..., 'http://www.stephenson.com/',
#         'http://www.stephenson.com/', 'http://www.stephenson.com/'],
#        [2, 2, 2, ..., 'http://www.hobbs.com/', 'http://www.hobbs.com/',
#         'http://www.hobbs.com/'],
#        [3, 3, 3, ..., 'http://www.lawrence.com/',
#         'http://www.lawrence.com/', 'http://www.lawrence.com/'],
#        ...,
#        [98, 98, 98, ..., 'https://www.ross.com/',
#         'https://www.ross.com/', 'https://www.ross.com/'],
#        [99, 99, 99, ..., 'http://watkins.info/', 'http://watkins.info/',
#         'http://watkins.info/'],
#        [100, 100, 100, ..., 'http://www.hatfield-saunders.net/',
#         'http://www.hatfield-saunders.net/',
#         'http://www.hatfield-saunders.net/']], dtype=object)

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd
customer_file = pd.read_csv(filepath_or_buffer = "insurance.csv")
plt.hist(customer_file['age'],color='blue')
plt.show()
