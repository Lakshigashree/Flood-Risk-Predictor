# %% [markdown]
# ## Multiple Condition

# %% [markdown]
# ## Level 3

# %%
secret_number=12
for i in range(0,7):
    user_input=int(input("Enter a number: "))
    if secret_number == user_input:
         print("Your guess is correct")
    elif secret_number < user_input:
        print("Too high")
    elif secret_number > user_input:
        print("Too low")
# Out:
# Enter a number:  13
# Too high
# Enter a number:  23
# Too high
# Enter a number:  43
# Too high
# Enter a number:  26
# Too high
# Enter a number:  78
# Too high
# Enter a number:  12
# Your guess is correct
# Enter a number:  10
# Too low

# %% [markdown]
# ## Level 4

# %%
secret_number=12
for i in range(0,7):
    user_input=int(input("Enter a number: "))
    if user_input<1 or user_input>100:
        print("Invalid")
    elif secret_number < user_input:
        print("Too high")
    elif secret_number > user_input:
        print("Too low")
    else : 
        print("Your guess is correct")
        break
if secret_number == user_input:
    print(f"Your have guessed the secret number {secret_number} in {i+1} attempts!")
# Out:
# Enter a number:  -1
# Invalid
# Enter a number:  13
# Too high
# Enter a number:  10
# Too low
# Enter a number:  12
# Your guess is correct
# Your have guessed the secret number 12 in 4 attempts!
