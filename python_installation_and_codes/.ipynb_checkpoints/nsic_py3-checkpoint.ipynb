# %% [markdown]
# ## Level 5

# %%
import random

# %%
random.randint(1,100)
# Out:
# 36

# %% [markdown]
# ### 5.1 for loop

# %%
print("Welcome to Number Guessing Game!")
print("Guess number between 1 to 100: ")

secret_number=random.randint(1,100)

for i in range(0,7):
    user_input=int(input("Enter a number: "))
    if user_input<1 or user_input>100:
        print("Invalid")
    elif secret_number < user_input:
        print("Too high")
    elif secret_number > user_input:
        print("Too low")
    else : 
        print("Your guess is correct")
        break
if secret_number == user_input:
    print(f"Your have guessed the secret number {secret_number} in {i+1} attempts!")
else:
    print("Sorry! Your attempts are Completed. Try Again.")
# Out:
# Welcome to Number Guessing Game!
# Guess number between 1 to 100:
# Enter a number:  -1
# Invalid
# Enter a number:  191
# Invalid
# Enter a number:  14
# Too low
# Enter a number:  25
# Too low
# Enter a number:  36
# Too low
# Enter a number:  67
# Too low
# Enter a number:  89
# Too high
# Sorry! Your attempts are Completed. Try Again.

# %% [markdown]
# ### 5.2 While loop

# %%
import random

print("Welcome to Number Guessing Game!")
print("Guess number between 1 to 100: ")

secret_number=random.randint(1,100)

while True:
    user_input=int(input("Enter a number: "))
    if user_input<1 or user_input>100:
        print("Invalid")
    elif secret_number < user_input:
        print("Too high")
    elif secret_number > user_input:
        print("Too low")
    else :
        print(f"Your have guessed the secret number {secret_number} in {i+1} attempts!")
        print("Your guess is correct")
        break
